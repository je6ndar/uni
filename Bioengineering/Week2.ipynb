# %% [markdown]
# ![image.png](attachment:54ff757f-671e-4612-a0e5-24a1b3ef9687.png)

# %% [markdown]
# ![image.png](attachment:327ad593-4763-40fd-877c-e2f4a048a4e2.png)

# %% [markdown]
# ![image.png](attachment:8526e4d2-beea-46a8-ac85-68a260676acd.png)

# %% [markdown]
# ![image.png](attachment:1ca4f37d-8f60-417b-a281-fd2264cb0665.png)

# %% [markdown]
# a) AUG GUU AGA GUC GCU AUU AAU GGG UUU GGC
#
# b) $1*4*4*6*4*3*2*16*2*3= 221184$

# %% [markdown]
# # Question2
#
# ![image.png](attachment:63888dfe-c354-4015-8977-f2f756baa303.png)
# ![image.png](attachment:1bf58292-0d30-4e70-b094-d9537bb6ffc9.png)

# %% [markdown]
# a) $\frac{1}{64} \cdot (\frac{61}{64})^{29} \cdot \frac{3}{64}$ Note: starting codon can be in the middle, it doesn't break the sequence.
#
# b) $\frac{1}{64} \cdot (\frac{61}{64})^{299} \cdot \frac{3}{64}$
#
# c) $2 \cdot 4*10^6 \frac{1}{64} \cdot (\frac{61}{64})^{29} \cdot \frac{3}{64} \approx 1455$
#
# d) TTGT ATG AGT GTG TCT ACC GCC AAG AGG TCG CTG GAT GTC GTT TCT CCG GGT TCA TTA GCG GAG TTT GAG GGT TCA AAA TCT CGT CAC GAT GAA AAG AAG TAG GCTACTTTA
#
# protein consisting of 32 amino acids

# %% [markdown]
# ![image.png](attachment:43b0c906-99d3-41f5-904d-f7b0ae08eec7.png)

# %% [markdown]
# a) We must code each of the amino acis by the combination of $5$ bases, as $2^5 = 32$, which allows us to code all 20 amino acids.
#
# b)
# - The number of amino acid sequences of length 2 $20^2 = 400$
# - The number of DNA sequences of length 3 $4^3 = 64$
# - The number of amino acid sequences of length 4 $20^4 = 160000$
# - The number of DNA sequences of length 5 $4^5 = 1024$

# %% [markdown]
# ![image.png](attachment:2a269d0e-a2b9-4923-8ddb-97c49bfea049.png)
# ![image.png](attachment:e9caeb0b-ec8e-4097-bf63-5ee0431dcc82.png)

# %% [markdown]
# ![image.png](attachment:965bdcf5-388f-4339-ae5e-278ea22b3a80.png)
#
# a) $4.6 \cdot 10^6 \cdot  2 \cdot 2 \cdot 8 = 2.3 \cdot 10^6$  bytes
#
#  $\text{Volumetric Density of SSD} = 2.6 \cdot 10^2 \text{ bytes/µm}^3 $

# %%
4.6 * 10**6 *  2 * 2 / 8
# Out:
# 2300000.0
