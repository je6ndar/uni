# %%
import numpy as np
from sympy import *
from dtumathtools import*

# %% [markdown]
# ![image.png](attachment:dbea6eb3-1f8d-4647-a506-f14da0a6b81a.png)
#
# $1000kcal = 4184kjoul$
#
# $M(ATP) = 507.2g/mol$
#
# $\frac{4184}{30} \cdot 507.2 = 70737.5g = 70.7kg$

# %% [markdown]
# ![image.png](attachment:d2314906-18c7-4634-8c50-f54fc8bbdca1.png)
#
# $distance = \sqrt{2Dt}$
#
# $t = \frac{distance^2}{2D} = \frac{(20\cdot10^{-9})^2}{2\cdot10^{-9}} = 200 \cdot 10^{-7}$

# %% [markdown]
# ![image.png](attachment:5ad4b605-1f5a-4b2d-9f17-f2aa8a7256c2.png)

# %% [markdown]
# $D(protein) = D(dopamine)/10$
#
# $t = \frac{(20\cdot10^{-9})^2}{2\cdot10^{-10}} = 200 \cdot 10^{-6}$

# %% [markdown]
# ![image.png](attachment:8635ce14-94fc-415f-82ae-0df021dcb036.png)
# ![image.png](attachment:4125f704-8bf8-497b-ab70-e7a88278756f.png)

# %%
t = symbols('t',nonnegative=True)
D = 5*10**(-10)
f1 = t*30*10**(-6)
distance = sqrt(D * t)
plt = dtuplot.plot(f1,(t,0,100), show=False)
plt.extend(dtuplot.plot(distance,(t,0,100), show=False))
plt.show()

# %% [markdown]
# ![image.png](attachment:36810ab7-5f40-4b20-9eb8-d3482bba1aea.png)

# %% [markdown]
# $\pi = MRT$, $M(mol/L)$ - molar concentration of the solution , $R = 0.08206$
#
# $\frac{m_{NaCl}}{m_{NaCl}+m_{H_2O}} = 0.263$
#
# $\rho = \frac{m_{NaCl}+m_{H_2O}}{V}$
#
# $m_{NaCl} = 0.263\cdot \rho \cdot V$
#
# $\pi = \frac{m_{NaCl}}{M_{NaCl} \cdot V}RT$
#
# $\pi = \frac{0.263 \cdot \rho \cdot V}{M_{NaCl}\cdot V} \cdot RT$

# %%
0.263*1202*0.08206/58.44 * 298
# Out:
# 132.2810963189596

# %% [markdown]
# b)

# %% [markdown]
# ![image.png](attachment:17071ca4-0f4b-4c32-8364-da0fc84bacad.png)

# %% [markdown]
# $h = \frac{2\gamma \cdot cos(\theta)}{\rho g r_0}$

# %%
gamm, thet, rho, r0, h = symbols('gamm, thet, rho, r0, h')
gamm = 0.07275
thet = 0
rho = 1000
h = 100

eq =  Eq(2*gamm * cos(thet)/(rho*9.81*r0),h)

solve(eq,r0)
# Out:
# [1.48318042813456e-7]

# %% [markdown]
# ![image.png](attachment:ce0d5adb-faa5-45ce-9029-4fcbfee88abc.png)

# %%
300000*pi*(2.5*10**(-6))**4/8/0.001/(pi*(2.5*10**(-6))**2)*1000
# Out:
# 0.234375000000000
