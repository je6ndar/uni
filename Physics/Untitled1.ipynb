# %%
import numpy as np
from sympy import*
import matplotlib.pyplot as plt
from dtumathtools import *

# %%
t = symbols('t')

# %%
B0 = 0.1 
R0 = 10
t0 = 2 * 10**(-3)
a = 0.2
f = pi*a**2*B0*exp(-t/t0)/R0/t0

# %%
dtuplot.plot(f, (t,2*10**(-3),30*10**(-3)))
