# %%
import numpy as np

# %% [markdown]
# # Lagrange polynomial
# ![image.png](attachment:18f1fc87-66e6-4d35-966b-2791eb8002c5.png)

# %% [markdown]
# # Exercise 7.1
# ![image.png](attachment:07217542-79b1-4129-a853-e6f8d3aeab7a.png)

# %%
def CardinalPolynomial(nodes, i, t):
    cardinals = []
    #loop that calculates ith polynomial
    for arg in t: 
        l = 1
        for index in range(i):
            if index == i: 
                pass
            else:
                l*=(t-x[index])/(x[i]-x[index])
        cardinals.append(x)
    return cardinals
