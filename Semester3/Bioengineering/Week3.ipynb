# %% [markdown]
# ![image.png](attachment:aaedcede-0887-46b3-ab52-7c080e9c41f4.png)
# ![image.png](attachment:b1443eaa-4bf7-4ae6-bf80-9a5381d05a87.png)

# %% [markdown]
# 1) It is gonna be the transition from ES to EP as this step requires the most amount of energy to overcome.
# 2) k2 is larger as reaction goes faster in this direction due to the lower energy barrier.
# 3) 75?

# %% [markdown]
# ![image.png](attachment:5c79085a-23ed-40a5-a6c4-ef0442380f1e.png)

# %% [markdown]
# a) $f_1 = k_b T \frac{3R}{N_1l_1^2} = -6*10^{-14}$
#
# $N_1 = \frac{10 * 10^{-6}}{50 * 10^{-9}} = 200$
#
# $N_2 = \frac{10 * 10^{-6}}{2.2 * 10^{-9}} = 4545$
#
# $f_2 = -6*10^{-14} \frac{200*(50*10^{-9})}{4545*(2.2*10^{-9})^2} = -1.4\cdot 10^{-12}$
#
# b) The module of the force required is increased.

# %% [markdown]
# ![image.png](attachment:5985ebdd-49c5-4ee5-9c6e-a9f848678c67.png)
# ![image.png](attachment:a91a7119-a773-4b4d-bb0d-076c33a63bec.png)
# ![image.png](attachment:eac928e0-ac87-48e8-afda-05b8104ae575.png)
# ![image.png](attachment:6928c10d-eb19-4c6e-8c47-a7486d491afc.png)

# %% [markdown]
# a) for example carbon dioxide conversion to methanol. it is considered as a difficult reaction as it requares to break double bound between carbon and oxigen, which is energy constly reaction without catalyst.
