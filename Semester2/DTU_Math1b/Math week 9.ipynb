# %%
from sympy import*
from dtumathtools import*
from sympy import cosh

# %%
x, y, u, v, a, h= symbols("x, y, u, v, a, h")

# %%
cosh(2*np.pi)
# Out:
# 267.746761483748

# %%
a=0.5
r = Matrix([u, a*cosh(u/a)])
f = r.row(1)[0]
sol = solve((a*cosh(u/a)-5),u)
dtuplot.plot_parametric(*r, (u, -1.5, 1.5))
dtuplot.plot(f, (u,0,5))
L = integrate(cosh(u/a), (u, sol[0], sol[1]))
L
# Out:
# 9.94987437106620

# %%
a= 0.5
sol = solve((a*cosh(u/a)-5),u)

# %%
sol[0]
# Out:
# -1.49661142306319

# %%
r.row(1)[0
# Out:
# 5*cosh(u/5)

# %%
f
# Out:
# 5*cosh(u/5)

# %%
f = atan2(y,x)

r = Matrix([v*cos(u),v*sin(u)])

dtuplot.plot3d(f.subs({x: r[0], y: r[1]}), (u, 0, 2*pi), (v, 0.5, 1))
# Out:
# /home/je6ndar/.local/lib/python3.10/site-packages/spb/series.py:604: UserWarning: NumPy is unable to evaluate with complex numbers some of the functions included in this symbolic expression: [atan2]. Hence, the evaluation will use real numbers. If you believe the resulting plot is incorrect, change the evaluation module by setting the `modules` keyword argument.
#   warnings.warn("NumPy is unable to evaluate with complex "

# %%
integrate((a**2 + v**2)**(-3/2),(v, -h, h))
# Out:
# 1.12837916709551*sqrt(pi)*h/(a**3.0*sqrt(1 + h**2/a**2))

# %%
A = Matrix([[1/8, 3/8],[3/8, 1/8]])
vec = A.eigenvects()
A
# Out:
# Matrix([
# [0.125, 0.375],
# [0.375, 0.125]])

# %%
lamda1 = vec[0][0]
lamda2 = vec[1][0]
l1 = vec[0][2][0]
l2 = vec[1][2][0]

# %%
k1, k2, k3, k4 = symbols("k1, k2, k3, k4")
r1 = Matrix([0,-1])
r2 = Matrix([0,0.5])
eq1 = Eq(k1*l1 + k2*l2, r1)
eq2 = Eq(k3*l1 + k4*l2, r2)

# %%
l1 , l2
# Out:
# (Matrix([
#  [-0.707106781186548],
#  [ 0.707106781186548]]),
#  Matrix([
#  [-0.707106781186548],
#  [-0.707106781186548]]))

# %%
sol2 = solve(eq2)

# %%
sol1 = solve(eq1)

# %%
eq1
# Out:
# Eq(Matrix([
# [-0.707106781186548*k1 - 0.707106781186548*k2],
# [ 0.707106781186548*k1 - 0.707106781186548*k2]]), Matrix([
# [ 0],
# [-1]]))

# %%
sol1[k1]*exp(lamda1 * u) * l1 + sol1[k2] * exp(lamda2 * u) * l2
# Out:
# Matrix([
# [-0.5*exp(0.5*u) + 0.5*exp(-0.25*u)],
# [-0.5*exp(0.5*u) - 0.5*exp(-0.25*u)]])

# %%
vec[0][0]
# Out:
# -0.250000000000000
